# %% [markdown]
# 测试过程：deepseek生成20个测试用例，将20个测试用例输入泰国旅游规划助手，得到结构化输出结果，将输出结果输入deepseek,deepseek进行打分，每个用例5分，总计100分
# 评分规则说明​（每个测试用例5分制）：
#
# ​基础合规性（2分）​
#
# 推荐结果完全满足所有约束条件（如穆斯林用例不出现酒吧）
# 出现任一违规项即扣2分
# ​标签匹配度（2分）​
#
# 每个预期标签匹配得0.5分（如4个标签需全中）
# 出现无关标签每个扣0.5分
# ​附加创新分（1分）​
#
# 推荐方案包含智能附加服务（如暴雨预警系统）
# 提供超出预期的解决方案（如宠物游包含宠物生日派对）
#
# 示例：
# 1号测试用例：家庭亲子游（6岁儿童）​
# 原始约束：
# json
# {
#   "约束条件": ["预算<3000泰铢/天", "7月出行", "每日交通时间<2小时"],
#   "预期标签": ["儿童游乐场", "室内场馆", "免门票"]
# }
# 评分分析：
# 评分维度	验证过程	得分
# ​基础合规性​	1. 总预算：(1200+4500+1800+900)/3天=2800泰铢/天 ✔️
# 2. 7月景点均开放 ✔️
# 3. 交通时间未标注 ❌	1.5/2
# ​标签匹配度​	1. 室内场馆×2 ✔️
# 2. 免门票（乍都乍市场）✔️
# 3. 缺少儿童游乐场 ❌	1.5/2
# ​附加创新分​	提供"婴儿推车租赁"创新服务 ✔️	1/1
# 突出问题：
# 交通模块未标注每日具体通勤时长，无法验证"<2小时"约束
# 乍都乍市场7月雨季露天活动存在风险（应推荐更多室内场馆）
# 最终得分：4/5

# %% [markdown]
# 评分总表
# 测试用例	基础合规性	标签匹配度	附加创新分	总分
# 1号	1.5	1.5	1	4.0
# 2号	1.0	1.5	1	3.5
# 3号	2.0	2.0	0	4.0
# 4号	1.0	0.5	0	1.5
# 5号	1.5	1.0	1	3.5
# 6号	1.0	0.5	1	2.5
# 7号	1.5	2.0	1	4.5
# 8号	1.5	2.0	1	4.5
# 9号	1.5	2.0	1	4.5
# 10号	1.5	2.0	1	4.5
# 11号	1.5	2.0	0	3.5
# 12号	1.5	2.0	0	3.5
# 13号	1.0	2.0	0	3.0
# 14号	1.5	2.0	1	4.5
# 15号	1.0	1.0	0	2.0
# 16号	1.0	2.0	0	3.0
# 17号	0.5	2.0	0	2.5
# 18号	1.0	2.0	1	4.0
# 19号	1.0	1.5	0	2.5
# 20号	1.5	2.0	1	4.5
#
# ​总分统计：
#
# python
# 总分 = sum(各用例总分) = 4.0 + 3.5 + 4.0 + 1.5 + 3.5 + 2.5 + 4.5 + 4.5 + 4.5 + 4.5 + 3.5 + 3.5 + 3.0 + 4.5 + 2.0 + 3.0 + 2.5 + 4.0 + 2.5 + 4.5 = 70.0
# ​平均分：
#
# python
# 平均分 = 总分 / 20 = 3.5/5
# ​达标分析：
#
# ​精准度​（标签匹配度达标率）：
# (标签匹配度总分 / 40) × 100% = (34.5/40) × 100% = 86.25%
# ​用户满意度​（附加创新分达标率）：
# (创新分总分 / 20) × 5 = (9/20) × 5 = 2.25/5

# %% [markdown]
# test_cases = [
#     {  # 1号测试用例
#         "用户类型": "家庭亲子游（6岁儿童）",
#         "约束条件": ["预算<3000泰铢/天", "7月出行", "每日交通时间<2小时"],
#         "预期标签": ["儿童游乐场", "室内场馆", "免门票"]
#     },
#     {  # 2号测试用例
#         "用户类型": "摄影发烧友",
#         "约束条件": ["追求日出/日落拍摄", "不接受人像摆拍", "设备防水需求"],
#         "预期标签": ["观景台", "自然奇观", "三脚架友好区"]
#     },
#     {  # 3号测试用例
#         "用户类型": "穆斯林游客",
#         "约束条件": ["halal饮食", "每日礼拜时间预留", "拒绝夜生活场所"],
#         "预期标签": ["清真餐厅", "祈祷室", "文化博物馆"]
#     },
#     {  # 4号测试用例
#         "用户类型": "轮椅使用者",
#         "约束条件": ["无障碍通道", "租借电动轮椅", "医疗急救站5km内"],
#         "预期标签": ["坡道设施", "无障碍卫生间", "电梯配置"]
#     },
#     {  # 5号测试用例
#         "用户类型": "商务会议团",
#         "约束条件": ["包含会议室预订", "距CBD<10km", "高端商务午餐"],
#         "预期标签": ["五星酒店", "视频会议设备", "米其林餐厅"]
#     },
#     {  # 6号测试用例
#         "用户类型": "背包客穷游",
#         "约束条件": ["床位预算<150泰铢/晚", "青旅社交氛围", "免费wifi必备"],
#         "预期标签": ["背包客聚集区", "公共厨房", "徒步路线"]
#     },
#     {  # 7号测试用例
#         "用户类型": "蜜月情侣",
#         "约束条件": ["私密性要求高", "烛光晚餐", "拒绝儿童区域"],
#         "预期标签": ["私人泳池别墅", "情侣SPA", "星空观景"]
#     },
#     {  # 8号测试用例
#         "用户类型": "素食主义者",
#         "约束条件": ["严格素食", "拒绝动物表演", "可持续旅游"],
#         "预期标签": ["有机农场", "植物工坊", "生态保护区"]
#     },
#     {  # 9号测试用例
#         "用户类型": "历史学者",
#         "约束条件": ["13-15世纪遗迹", "专业讲解员", "文献查阅权限"],
#         "预期标签": ["UNESCO遗产", "考古遗址", "学术访问通道"]
#     },
#     {  # 10号测试用例
#         "用户类型": "医疗旅游",
#         "约束条件": ["医美诊所资质", "术后恢复设施", "中英双语医护"],
#         "预期标签": ["JCI认证医院", "康复中心", "医疗接送"]
#     },
#     {  # 11号测试用例
#         "用户类型": "极限运动爱好者",
#         "约束条件": ["深潜PADI认证", "洞穴探险许可", "保险包含高危项目"],
#         "预期标签": ["专业教练陪同", "装备租赁", "应急救援点"]
#     },
#     {  # 12号测试用例
#         "用户类型": "周末快闪游",
#         "约束条件": ["仅周六日出行", "曼谷周边100km", "凌晨航班兼容"],
#         "预期标签": ["机场快线直达", "一日游套餐", "行李寄存"]
#     },
#     {  # 13号测试用例
#         "用户类型": "宠物同行游",
#         "约束条件": ["18kg犬只随行", "宠物友好住宿", "应急兽医信息"],
#         "预期标签": ["宠物泳池", "遛狗公园", "宠物推车租赁"]
#     },
#     {  # 14号测试用例
#         "用户类型": "朝圣之旅",
#         "约束条件": ["佛教圣地巡礼", "禅修课程体验", "过午不食安排"],
#         "预期标签": ["高僧讲座", "止语禅房", "斋饭供应"]
#     },
#     {  # 15号测试用例
#         "用户类型": "退休银发族",
#         "约束条件": ["午休2小时预留", "急救药品冷链", "拒绝台阶>20级"],
#         "预期标签": ["电瓶车接驳", "血压监测站", "长椅密度>5个/km"]
#     },
#     {  # 16号测试用例
#         "用户类型": "同性伴侣",
#         "约束条件": ["LGBTQ+友好标识", "彩虹主题活动", "法律权益咨询"],
#         "预期标签": ["同志酒吧", "性别友善厕所", "伴侣签证协助"]
#     },
#     {  # 17号测试用例
#         "用户类型": "雨季出行",
#         "约束条件": ["8月出行", "拒绝户外涉水", "备用室内方案"],
#         "预期标签": ["雨具租赁", "防洪路线", "暴雨预警系统"]
#     },
#     {  # 18号测试用例
#         "用户类型": "文化禁忌敏感者",
#         "约束条件": ["避讳皇室话题", "不接触僧侣", "衣着保守要求"],
#         "预期标签": ["非政治景点", "世俗化场馆", "长袖服装租赁"]
#     },
#     {  # 19号测试用例
#         "用户类型": "数字游民",
#         "约束条件": ["稳定220V电源", "5G网速>100Mbps", "共享办公空间"],
#         "预期标签": ["充电桩密度", "网络压力测试", "静音会议室"]
#     },
#     {  # 20号测试用例
#         "用户类型": "重复游客",
#         "约束条件": ["已去过大皇宫/水上市场", "寻求深度体验", "拒绝网红景点"],
#         "预期标签": ["本地市集", "手工艺村落", "非旅游区美食"]
#     }
# ]

# %% [markdown]
# [
#   {
#     "行程概要": {
#       "出行日期": "2024-07-12至2024-07-15",
#       "用户类型": "家庭亲子游",
#       "总人数": 3
#     },
#     "景点清单": [
#       {
#         "名称": "暹罗海洋世界",
#         "类型": "室内场馆",
#         "适合人群": ["儿童", "家庭"],
#         "日均客流": "高峰时段10:00-14:00",
#         "推荐理由": "东南亚最大水族馆，提供儿童互动项目"
#       },
#       {
#         "名称": "曼谷儿童博物馆",
#         "类型": "室内场馆",
#         "适合人群": ["儿童", "家庭"],
#         "日均客流": "高峰时段09:00-12:00",
#         "推荐理由": "寓教于乐，适合亲子互动"
#       },
#       {
#         "名称": "乍都乍周末市场",
#         "类型": "室外市场",
#         "适合人群": ["家庭"],
#         "日均客流": "高峰时段15:00-18:00",
#         "推荐理由": "免门票，适合家庭购物和体验本地文化"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "包车", "费用": 1200, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "曼谷儿童友好酒店", "费用": 4500},
#       "门票": {"成人票": 2, "儿童票": 1, "总价": 1800},
#       "餐饮": {"人均预算": 300, "特色餐厅": ["亲子主题餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["婴儿推车租赁", "紧急医疗联络"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.5,
#       "文化标签": ["亲子教育", "泰国海洋文化"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "摄影发烧友",
#       "总人数": 1
#     },
#     "景点清单": [
#       {
#         "名称": "大城府遗址",
#         "类型": "自然奇观",
#         "适合人群": ["摄影爱好者"],
#         "日均客流": "高峰时段06:00-08:00",
#         "推荐理由": "日出拍摄绝佳地点，历史遗迹丰富"
#       },
#       {
#         "名称": "考艾国家公园",
#         "类型": "自然奇观",
#         "适合人群": ["摄影爱好者"],
#         "日均客流": "高峰时段17:00-19:00",
#         "推荐理由": "日落美景，野生动物拍摄"
#       },
#       {
#         "名称": "曼谷观景台",
#         "类型": "观景台",
#         "适合人群": ["摄影爱好者"],
#         "日均客流": "高峰时段18:00-20:00",
#         "推荐理由": "城市全景，适合夜景拍摄"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "自驾", "费用": 2000, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "曼谷摄影主题酒店", "费用": 6000},
#       "门票": {"成人票": 1, "总价": 1500},
#       "餐饮": {"人均预算": 400, "特色餐厅": ["摄影爱好者聚集餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["三脚架租赁", "防水相机套"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.0,
#       "文化标签": ["摄影艺术", "自然风光"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "穆斯林游客",
#       "总人数": 2
#     },
#     "景点清单": [
#       {
#         "名称": "曼谷大清真寺",
#         "类型": "文化博物馆",
#         "适合人群": ["穆斯林"],
#         "日均客流": "高峰时段12:00-14:00",
#         "推荐理由": "泰国最大的清真寺，提供祈祷室"
#       },
#       {
#         "名称": "泰国伊斯兰文化中心",
#         "类型": "文化博物馆",
#         "适合人群": ["穆斯林"],
#         "日均客流": "高峰时段10:00-12:00",
#         "推荐理由": "了解泰国伊斯兰文化，设有祈祷室"
#       },
#       {
#         "名称": "曼谷国家博物馆",
#         "类型": "文化博物馆",
#         "适合人群": ["穆斯林"],
#         "日均客流": "高峰时段09:00-11:00",
#         "推荐理由": "丰富的历史文化展示，避免夜生活场所"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "公共交通", "费用": 800, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "曼谷清真酒店", "费用": 5000},
#       "门票": {"成人票": 2, "总价": 1000},
#       "餐饮": {"人均预算": 350, "特色餐厅": ["halal认证餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["祈祷室提供", "halal饮食安排"],
#     "文化适配": {
#       "宗教禁忌": "符合伊斯兰教规",
#       "本地化程度": 4.0,
#       "文化标签": ["伊斯兰文化", "泰国历史"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "轮椅使用者",
#       "总人数": 1
#     },
#     "景点清单": [
#       {
#         "名称": "曼谷大皇宫",
#         "类型": "文化博物馆",
#         "适合人群": ["轮椅使用者"],
#         "日均客流": "高峰时段09:00-11:00",
#         "推荐理由": "无障碍通道完善，历史文化丰富"
#       },
#       {
#         "名称": "暹罗购物中心",
#         "类型": "室内场馆",
#         "适合人群": ["轮椅使用者"],
#         "日均客流": "高峰时段13:00-15:00",
#         "推荐理由": "无障碍设施齐全，购物便利"
#       },
#       {
#         "名称": "曼谷艺术文化中心",
#         "类型": "室内场馆",
#         "适合人群": ["轮椅使用者"],
#         "日均客流": "高峰时段10:00-12:00",
#         "推荐理由": "无障碍通道，艺术展览丰富"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "无障碍出租车", "费用": 1500, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "曼谷无障碍酒店", "费用": 6000},
#       "门票": {"成人票": 1, "总价": 1200},
#       "餐饮": {"人均预算": 400, "特色餐厅": ["无障碍餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["电动轮椅租赁", "医疗急救站信息"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.2,
#       "文化标签": ["泰国文化", "无障碍旅游"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "商务会议团",
#       "总人数": 5
#     },
#     "景点清单": [
#       {
#         "名称": "曼谷国际贸易展览中心",
#         "类型": "会议中心",
#         "适合人群": ["商务人士"],
#         "日均客流": "高峰时段09:00-17:00",
#         "推荐理由": "高端会议设施，距CBD近"
#       },
#       {
#         "名称": "四季酒店会议室",
#         "类型": "五星酒店",
#         "适合人群": ["商务人士"],
#         "日均客流": "高峰时段09:00-17:00",
#         "推荐理由": "豪华会议室，高端商务午餐"
#       },
#       {
#         "名称": "曼谷中央商务区",
#         "类型": "商业区",
#         "适合人群": ["商务人士"],
#         "日均客流": "高峰时段10:00-18:00",
#         "推荐理由": "商务活动集中地，方便洽谈"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "商务车", "费用": 3000, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "曼谷四季酒店", "费用": 25000},
#       "门票": {"成人票": 5, "总价": 5000},
#       "餐饮": {"人均预算": 1000, "特色餐厅": ["米其林餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["会议室预订", "商务翻译"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.8,
#       "文化标签": ["商务活动", "高端服务"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "背包客穷游",
#       "总人数": 1
#     },
#     "景点清单": [
#       {
#         "名称": "考山路",
#         "类型": "背包客聚集区",
#         "适合人群": ["背包客"],
#         "日均客流": "高峰时段18:00-22:00",
#         "推荐理由": "青旅集中，社交氛围浓厚"
#       },
#       {
#         "名称": "曼谷国家博物馆",
#         "类型": "文化博物馆",
#         "适合人群": ["背包客"],
#         "日均客流": "高峰时段09:00-11:00",
#         "推荐理由": "免费入场，文化体验丰富"
#       },
#       {
#         "名称": "乍都乍周末市场",
#         "类型": "室外市场",
#         "适合人群": ["背包客"],
#         "日均客流": "高峰时段15:00-18:00",
#         "推荐理由": "免费入场，适合购物和体验本地文化"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "公共交通", "费用": 400, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "考山路青旅", "费用": 1200},
#       "门票": {"成人票": 1, "总价": 0},
#       "餐饮": {"人均预算": 150, "特色餐厅": ["街头小吃"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["免费wifi", "公共厨房"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.5,
#       "文化标签": ["背包客文化", "泰国市井生活"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "蜜月情侣",
#       "总人数": 2
#     },
#     "景点清单": [
#       {
#         "名称": "普吉岛私人泳池别墅",
#         "类型": "私人泳池别墅",
#         "适合人群": ["情侣"],
#         "日均客流": "高峰时段无限制",
#         "推荐理由": "私密性高，浪漫氛围"
#       },
#       {
#         "名称": "普吉岛情侣SPA",
#         "类型": "情侣SPA",
#         "适合人群": ["情侣"],
#         "日均客流": "高峰时段14:00-16:00",
#         "推荐理由": "放松身心，增进感情"
#       },
#       {
#         "名称": "普吉岛星空观景",
#         "类型": "星空观景",
#         "适合人群": ["情侣"],
#         "日均客流": "高峰时段20:00-22:00",
#         "推荐理由": "浪漫的星空体验，适合求婚或纪念日"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "包车", "费用": 2000, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "普吉岛私人泳池别墅", "费用": 15000},
#       "门票": {"成人票": 2, "总价": 0},
#       "餐饮": {"人均预算": 1000, "特色餐厅": ["海边烛光晚餐"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["私人管家服务", "浪漫活动策划"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.7,
#       "文化标签": ["浪漫旅行", "高端体验"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "素食主义者",
#       "总人数": 1
#     },
#     "景点清单": [
#       {
#         "名称": "清迈有机农场",
#         "类型": "有机农场",
#         "适合人群": ["素食主义者"],
#         "日均客流": "高峰时段09:00-11:00",
#         "推荐理由": "体验有机种植，品尝新鲜素食"
#       },
#       {
#         "名称": "清迈植物工坊",
#         "类型": "植物工坊",
#         "适合人群": ["素食主义者"],
#         "日均客流": "高峰时段14:00-16:00",
#         "推荐理由": "学习植物知识，制作素食产品"
#       },
#       {
#         "名称": "清迈生态保护区",
#         "类型": "生态保护区",
#         "适合人群": ["素食主义者"],
#         "日均客流": "高峰时段10:00-12:00",
#         "推荐理由": "亲近自然，支持可持续旅游"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "自行车租赁", "费用": 500, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "清迈素食友好酒店", "费用": 4000},
#       "门票": {"成人票": 1, "总价": 1500},
#       "餐饮": {"人均预算": 300, "特色餐厅": ["素食餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["素食菜单提供", "环保活动参与"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.3,
#       "文化标签": ["素食文化", "可持续旅游"]
#     }
#   },
#   {
#     "行程概要": {
#       "出行日期": "2024-08-12至2024-08-15",
#       "用户类型": "历史学者",
#       "总人数": 1
#     },
#     "景点清单": [
#       {
#         "名称": "素可泰历史公园",
#         "类型": "UNESCO遗产",
#         "适合人群": ["历史学者"],
#         "日均客流": "高峰时段09:00-11:00",
#         "推荐理由": "13-15世纪遗迹，丰富的历史研究价值"
#       },
#       {
#         "名称": "大城府遗址",
#         "类型": "考古遗址",
#         "适合人群": ["历史学者"],
#         "日均客流": "高峰时段09:00-11:00",
#         "推荐理由": "历史遗迹丰富，适合考古研究"
#       },
#       {
#         "名称": "曼谷国家博物馆",
#         "类型": "学术访问通道",
#         "适合人群": ["历史学者"],
#         "日均客流": "高峰时段10:00-12:00",
#         "推荐理由": "提供文献查阅权限，专业讲解员服务"
#       }
#     ],
#     "费用明细": {
#       "交通": {"类型": "包车", "费用": 2000, "货币单位": "泰铢"},
#       "住宿": {"酒店名": "曼谷历史主题酒店", "费用": 6000},
#       "门票": {"成人票": 1, "总价": 2000},
#       "餐饮": {"人均预算": 500, "特色餐厅": ["历史主题餐厅"]}
#     },
#     "约束验证": {
#       "预算合规": true,
#       "季节适配": true,
#       "禁忌规避": true
#     },
#     "特殊服务": ["专业讲解员预约", "文献查阅权限"],
#     "文化适配": {
#       "宗教禁忌": "无敏感内容",
#       "本地化程度": 4.8,
#       "文化标签": ["历史研究", "泰国文化遗产"]
#     }
#   },  10. 医疗旅游
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "医疗旅游",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷JCI认证医院",
#       "类型": "JCI认证医院",
#       "适合人群": ["医疗旅游者"],
#       "日均客流": "高峰时段09:00-11:00",
#       "推荐理由": "国际医疗服务，术后恢复设施完善"
#     },
#     {
#       "名称": "曼谷康复中心",
#       "类型": "康复中心",
#       "适合人群": ["医疗旅游者"],
#       "日均客流": "高峰时段14:00-16:00",
#       "推荐理由": "专业的康复治疗，中英双语医护服务"
#     },
#     {
#       "名称": "曼谷医疗接送服务",
#       "类型": "医疗接送",
#       "适合人群": ["医疗旅游者"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "便捷的医疗接送服务，确保安全"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "医疗接送", "费用": 1500, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷医疗主题酒店", "费用": 8000},
#     "门票": {"成人票": 1, "总价": 0},
#     "餐饮": {"人均预算": 400, "特色餐厅": ["健康餐饮"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["医疗预约服务", "术后恢复指导"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.5,
#     "文化标签": ["医疗旅游", "健康服务"]
#   }
# }
# ​11. 极限运动爱好者
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "极限运动爱好者",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "普吉岛深潜",
#       "类型": "专业教练陪同",
#       "适合人群": ["极限运动爱好者"],
#       "日均客流": "高峰时段08:00-10:00",
#       "推荐理由": "PADI认证潜水中心，专业教练陪同"
#     },
#     {
#       "名称": "清迈洞穴探险",
#       "类型": "洞穴探险许可",
#       "适合人群": ["极限运动爱好者"],
#       "日均客流": "高峰时段09:00-11:00",
#       "推荐理由": "探险许可，专业设备租赁"
#     },
#     {
#       "名称": "清迈应急救援点",
#       "类型": "应急救援点",
#       "适合人群": ["极限运动爱好者"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "提供紧急救援服务，保障安全"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "自驾", "费用": 2000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "清迈探险主题酒店", "费用": 6000},
#     "门票": {"成人票": 1, "总价": 3000},
#     "餐饮": {"人均预算": 500, "特色餐厅": ["探险者餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["专业教练预约", "探险装备租赁"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.2,
#     "文化标签": ["极限运动", "探险体验"]
#   }
# }
# ​12. 周末快闪游
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-10至2024-08-11",
#     "用户类型": "周末快闪游",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷一日游套餐",
#       "类型": "一日游套餐",
#       "适合人群": ["快闪游客"],
#       "日均客流": "高峰时段08:00-18:00",
#       "推荐理由": "时间紧凑，体验丰富"
#     },
#     {
#       "名称": "曼谷机场快线",
#       "类型": "机场快线直达",
#       "适合人群": ["快闪游客"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "快速到达市中心，方便凌晨航班"
#     },
#     {
#       "名称": "曼谷行李寄存服务",
#       "类型": "行李寄存",
#       "适合人群": ["快闪游客"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "方便临时寄存行李，轻松游玩"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "机场快线", "费用": 500, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷快捷酒店", "费用": 2000},
#     "门票": {"成人票": 1, "总价": 1000},
#     "餐饮": {"人均预算": 300, "特色餐厅": ["快闪游客推荐餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["一日游套餐预订", "行李寄存服务"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.0,
#     "文化标签": ["快闪旅游", "便捷服务"]
#   }
# }
# ​13. 宠物同行游
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "宠物同行游",
#     "总人数": 2
#   },
#   "景点清单": [
#     {
#       "名称": "普吉岛宠物泳池",
#       "类型": "宠物泳池",
#       "适合人群": ["宠物主人"],
#       "日均客流": "高峰时段10:00-12:00",
#       "推荐理由": "宠物可以一起游泳，增加乐趣"
#     },
#     {
#       "名称": "普吉岛遛狗公园",
#       "类型": "遛狗公园",
#       "适合人群": ["宠物主人"],
#       "日均客流": "高峰时段16:00-18:00",
#       "推荐理由": "宠物可以自由奔跑，社交互动"
#     },
#     {
#       "名称": "普吉岛宠物推车租赁",
#       "类型": "宠物推车租赁",
#       "适合人群": ["宠物主人"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "方便携带宠物出行，减轻负担"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "宠物友好出租车", "费用": 2000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "普吉岛宠物友好酒店", "费用": 8000},
#     "门票": {"成人票": 2, "总价": 1000},
#     "餐饮": {"人均预算": 500, "特色餐厅": ["宠物友好餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["宠物泳池使用", "遛狗公园通行证"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.3,
#     "文化标签": ["宠物友好", "户外活动"]
#   }
# }
# ​14. 朝圣之旅
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "朝圣之旅",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "清迈佛教圣地",
#       "类型": "高僧讲座",
#       "适合人群": ["朝圣者"],
#       "日均客流": "高峰时段06:00-08:00",
#       "推荐理由": "朝圣之旅的重要地点，体验佛教文化"
#     },
#     {
#       "名称": "清迈禅修中心",
#       "类型": "止语禅房",
#       "适合人群": ["朝圣者"],
#       "日均客流": "高峰时段14:00-16:00",
#       "推荐理由": "提供禅修课程，静心修行"
#     },
#     {
#       "名称": "清迈斋饭供应",
#       "类型": "斋饭供应",
#       "适合人群": ["朝圣者"],
#       "日均客流": "高峰时段12:00-13:00",
#       "推荐理由": "体验过午不食的传统，净化心灵"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "公共交通", "费用": 1000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "清迈禅修主题酒店", "费用": 5000},
#     "门票": {"成人票": 1, "总价": 500},
#     "餐饮": {"人均预算": 200, "特色餐厅": ["素食餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["禅修课程预约", "斋饭安排"],
#   "文化适配": {
#     "宗教禁忌": "符合佛教教规",
#     "本地化程度": 4.7,
#     "文化标签": ["佛教文化", "心灵修行"]
#   }
# }
# ​15. 退休银发族
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "退休银发族",
#     "总人数": 2
#   },
#   "景点清单": [
#     {
#       "名称": "清迈电瓶车接驳服务",
#       "类型": "电瓶车接驳",
#       "适合人群": ["退休银发族"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "方便出行，减少步行"
#     },
#     {
#       "名称": "清迈血压监测站",
#       "类型": "血压监测站",
#       "适合人群": ["退休银发族"],
#       "日均客流": "高峰时段09:00-11:00",
#       "推荐理由": "提供健康监测，关注身体状况"
#     },
#     {
#       "名称": "清迈长椅设施",
#       "类型": "长椅设施",
#       "适合人群": ["退休银发族"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "方便休息，密度适中"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "电瓶车租赁", "费用": 1500, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "清迈银发族友好酒店", "费用": 7000},
#     "门票": {"成人票": 2, "总价": 1000},
#     "餐饮": {"人均预算": 400, "特色餐厅": ["健康餐饮"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["健康监测服务", "午休安排"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.5,
#     "文化标签": ["银发族旅游", "健康养生"]
#   }
# }16. 同性伴侣
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "同性伴侣",
#     "总人数": 2
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷同志酒吧",
#       "类型": "同志酒吧",
#       "适合人群": ["LGBTQ+社群"],
#       "日均客流": "高峰时段21:00-23:00",
#       "推荐理由": "LGBTQ+友好环境，社交娱乐"
#     },
#     {
#       "名称": "曼谷性别友善厕所",
#       "类型": "性别友善厕所",
#       "适合人群": ["LGBTQ+社群"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "提供性别友善设施，尊重多元性别"
#     },
#     {
#       "名称": "曼谷伴侣签证协助",
#       "类型": "伴侣签证协助",
#       "适合人群": ["同性伴侣"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "提供签证咨询和办理服务"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "出租车", "费用": 2000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷LGBTQ+友好酒店", "费用": 8000},
#     "门票": {"成人票": 2, "总价": 0},
#     "餐饮": {"人均预算": 500, "特色餐厅": ["LGBTQ+主题餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["LGBTQ+活动信息", "伴侣签证咨询"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.6,
#     "文化标签": ["LGBTQ+文化", "多元包容"]
#   }
# }
# ​17. 雨季出行
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "雨季出行",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷雨具租赁服务",
#       "类型": "雨具租赁",
#       "适合人群": ["雨季出行者"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "提供雨具租赁，应对突发天气"
#     },
#     {
#       "名称": "曼谷防洪路线规划",
#       "类型": "防洪路线",
#       "适合人群": ["雨季出行者"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "规划安全路线，避免积水地区"
#     },
#     {
#       "名称": "曼谷暴雨预警系统",
#       "类型": "暴雨预警系统",
#       "适合人群": ["雨季出行者"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "提供实时天气信息，确保安全出行"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "出租车", "费用": 2000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷雨季出行酒店", "费用": 6000},
#     "门票": {"成人票": 1, "总价": 0},
#     "餐饮": {"人均预算": 400, "特色餐厅": ["室内餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["雨具租赁", "防洪路线咨询"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.0,
#     "文化标签": ["雨季出行", "安全措施"]
#   }
# }
# ​18. 文化禁忌敏感者
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "文化禁忌敏感者",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷非政治景点",
#       "类型": "非政治景点",
#       "适合人群": ["文化禁忌敏感者"],
#       "日均客流": "高峰时段09:00-11:00",
#       "推荐理由": "避免敏感话题，文化体验丰富"
#     },
#     {
#       "名称": "曼谷世俗化场馆",
#       "类型": "世俗化场馆",
#       "适合人群": ["文化禁忌敏感者"],
#       "日均客流": "高峰时段10:00-12:00",
#       "推荐理由": "尊重文化差异，避免宗教冲突"
#     },
#     {
#       "名称": "曼谷长袖服装租赁",
#       "类型": "长袖服装租赁",
#       "适合人群": ["文化禁忌敏感者"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "提供符合文化要求的服装，尊重当地习俗"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "公共交通", "费用": 1000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷文化敏感者友好酒店", "费用": 5000},
#     "门票": {"成人票": 1, "总价": 1000},
#     "餐饮": {"人均预算": 300, "特色餐厅": ["文化主题餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["文化禁忌咨询", "服装租赁服务"],
#   "文化适配": {
#     "宗教禁忌": "符合文化敏感者需求",
#     "本地化程度": 4.3,
#     "文化标签": ["文化尊重", "泰国习俗"]
#   }
# }
# ​19. 数字游民
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "数字游民",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷共享办公空间",
#       "类型": "共享办公空间",
#       "适合人群": ["数字游民"],
#       "日均客流": "高峰时段09:00-17:00",
#       "推荐理由": "提供稳定电源和高速网络，适合远程工作"
#     },
#     {
#       "名称": "曼谷充电桩设施",
#       "类型": "充电桩密度",
#       "适合人群": ["数字游民"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "充电设施遍布，方便设备充电"
#     },
#     {
#       "名称": "曼谷网络压力测试",
#       "类型": "网络压力测试",
#       "适合人群": ["数字游民"],
#       "日均客流": "高峰时段无限制",
#       "推荐理由": "确保网络稳定，满足工作需求"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "公共交通", "费用": 1000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷数字游民友好酒店", "费用": 6000},
#     "门票": {"成人票": 1, "总价": 0},
#     "餐饮": {"人均预算": 400, "特色餐厅": ["数字游民主题餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["共享办公空间预订", "网络速度测试"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.4,
#     "文化标签": ["数字游民文化", "远程工作环境"]
#   }
# }
# ​20. 重复游客
# json
# {
#   "行程概要": {
#     "出行日期": "2024-08-12至2024-08-15",
#     "用户类型": "重复游客",
#     "总人数": 1
#   },
#   "景点清单": [
#     {
#       "名称": "曼谷本地市集",
#       "类型": "本地市集",
#       "适合人群": ["深度游游客"],
#       "日均客流": "高峰时段15:00-18:00",
#       "推荐理由": "体验本地生活，避开网红景点"
#     },
#     {
#       "名称": "曼谷手工艺村落",
#       "类型": "手工艺村落",
#       "适合人群": ["深度游游客"],
#       "日均客流": "高峰时段10:00-12:00",
#       "推荐理由": "了解手工艺文化，购买独特纪念品"
#     },
#     {
#       "名称": "曼谷非旅游区美食",
#       "类型": "非旅游区美食",
#       "适合人群": ["深度游游客"],
#       "日均客流": "高峰时段18:00-20:00",
#       "推荐理由": "品尝地道美食，体验当地风味"
#     }
#   ],
#   "费用明细": {
#     "交通": {"类型": "公共交通", "费用": 1000, "货币单位": "泰铢"},
#     "住宿": {"酒店名": "曼谷本地特色酒店", "费用": 5000},
#     "门票": {"成人票": 1, "总价": 0},
#     "餐饮": {"人均预算": 500, "特色餐厅": ["本地美食餐厅"]}
#   },
#   "约束验证": {
#     "预算合规": true,
#     "季节适配": true,
#     "禁忌规避": true
#   },
#   "特殊服务": ["本地导游服务", "手工艺体验"],
#   "文化适配": {
#     "宗教禁忌": "无敏感内容",
#     "本地化程度": 4.6,
#     "文化标签": ["深度旅游", "泰国本地文化"]
#   }
# }
